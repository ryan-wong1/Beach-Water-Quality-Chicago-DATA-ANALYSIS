# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\Ryan Wong\Desktop\Beach Water Quality Cleaned.xlsx")

df
# Out:
#               Beach Name   Measurement Timestamp  Water Temperature  \
# 0          Calumet Beach  04/07/2018 12:30:00 AM               21.7
# 1      Ohio Street Beach  06/14/2019 07:00:00 PM               16.0
# 2      Ohio Street Beach  05/16/2018 01:00:00 PM               21.7
# 3      Ohio Street Beach  05/16/2018 02:00:00 PM               21.9
# 4      Ohio Street Beach  06/04/2018 09:00:00 AM               23.0
# ...                  ...                     ...                ...
# 45851  Ohio Street Beach  09/17/2024 09:00:00 PM               22.9
# 45852  Ohio Street Beach  09/17/2024 10:00:00 PM               22.4
# 45853  Ohio Street Beach  09/17/2024 11:00:00 PM               21.9
# 45854  Ohio Street Beach  09/18/2024 12:00:00 AM               21.4
# 45855  Ohio Street Beach  09/18/2024 01:00:00 AM               21.1
#
#        Turbidity  Transducer Depth  Wave Height  Wave Period  Battery Life  \
# ...

# %%
#QUESTIONS FOR ANALYSIS:

#Do certain beaches have higher averages of measurements than others?
#How do the different months/seasons vary in terms of measurements than others? What about time of day? And years?
#What is the correlation to battery life to time of day/month or beach location?
#What is the correlation to water temperature and turbidity to wave height and wave period?

#Are there any extreme outliers in distribution of this dataset?
#How frequently is each beach measured?


df.info()
#Turbidity = How clear the water is. How many particles are affecting water transparency. The higher the turbidity, the more foggy the water is
#Wave Period = Wave frequency. The lower the number, the closer the distance between waves (more choppy water conditions). Higher indicates wider distance between waves (more calm water conditions)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45856 entries, 0 to 45855
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Beach Name             45856 non-null  object
#  1   Measurement Timestamp  45856 non-null  object
#  2   Water Temperature      43702 non-null  float64
#  3   Turbidity              43702 non-null  float64
#  4   Transducer Depth       10034 non-null  float64
#  5   Wave Height            44592 non-null  float64
#  6   Wave Period            44592 non-null  float64
#  7   Battery Life           45470 non-null  float64
#  8   Date                   45856 non-null  datetime64[ns]
#  9   Time                   45856 non-null  object
#  10  Month                  45856 non-null  int64
#  11  Year                   45856 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 4.2+ MB

# %%
df.describe()
#FINDINGS:
#near equal amount of data for Water Temp, Turbidity, Wave Height, Wave Period, and Battery Life
#only 1/4th of data available for Transducer Depth, most values NaN
#Turbidity max value (1683.48) abormally high compared to 50th (1.35) and 75th (2.94) percentile
# Out:
#        Water Temperature     Turbidity  Transducer Depth   Wave Height  \
# count       43702.000000  43702.000000      10034.000000  44592.000000
# mean           19.691584      5.904444          1.570235      0.168741
# std             3.413810     31.914919          0.175118      0.091644
# min             0.000000      0.000000         -0.082000      0.000000
# 25%            17.300000      0.740000          1.426000      0.107000
# 50%            20.000000      1.350000          1.578000      0.151000
# 75%            22.500000      2.940000          1.721000      0.201000
# max            37.300000   1683.480000          2.214000      1.467000
#
#         Wave Period  Battery Life         Month          Year
# count  44592.000000  45470.000000  45856.000000  45856.000000
# mean       3.867878     11.256213      7.143405   2016.540060
# std        1.560330      0.957063      1.127379      2.974608
# min        1.000000      0.000000      4.000000   2013.000000
# ...

# %%
df.isnull().sum()
# Out:
# Beach Name                   0
# Measurement Timestamp        0
# Water Temperature         2154
# Turbidity                 2154
# Transducer Depth         35822
# Wave Height               1264
# Wave Period               1264
# Battery Life               386
# Date                         0
# Time                         0
# Month                        0
# Year                         0
# dtype: int64

# %%
df.nunique()
# Out:
# Beach Name                   8
# Measurement Timestamp    21734
# Water Temperature          211
# Turbidity                 3683
# Transducer Depth           775
# Wave Height                629
# Wave Period                 70
# Battery Life               102
# Date                       973
# Time                        30
# Month                        7
# Year                        11
# dtype: int64

# %%
#Do certain beaches have higher averages of measurements than others?

df.groupby('Beach Name').mean().sort_values(by='Water Temperature', ascending=False)
# Out:
#                         Water Temperature  Turbidity  Transducer Depth  \
# Beach Name
# Ohio Street Beach               20.623662   8.964216          1.735757
# Calumet Beach                   20.373104   1.886594          1.449376
# Rainbow Beach                   18.741250   3.164116          1.553982
# Montrose Beach                  18.640534   2.898791          1.638710
# 63rd Street Beach               18.459901   4.313150          1.753354
# Osterman Beach                  17.933615   8.707598          1.358719
# New Site                              NaN        NaN               NaN
# Ohio Street Beach Buoy                NaN        NaN               NaN
#
#                         Wave Height  Wave Period  Battery Life     Month  \
# Beach Name
# Ohio Street Beach          0.156343     3.685255     11.545114  7.197949
# Calumet Beach              0.152585     3.532365     10.972391  7.207001
# Rainbow Beach              0.203868     4.278459     11.198938  7.305429
# ...

# %%
#How do the different months/seasons vary in terms of measurements than others? What about time of day? And years?

#month/season:
df.groupby('Month')[['Water Temperature', 'Turbidity', 'Transducer Depth', 'Wave Height', 'Wave Period', 'Battery Life']].mean()
# Out:
#        Water Temperature  Turbidity  Transducer Depth  Wave Height  \
# Month
# 4              21.700000   3.150000               NaN     0.389000
# 5              14.751655  10.579902          1.456138     0.174384
# 6              17.542685   4.608764          1.534947     0.169373
# 7              20.298675   3.974617          1.587278     0.168488
# 8              22.004947   8.545174          1.594937     0.170761
# 9              20.235338   4.953000          1.630908     0.170799
# 10             15.757143  71.691429               NaN     0.020299
#
#        Wave Period  Battery Life
# Month
# 4         3.000000      0.000000
# 5         3.808161     11.802875
# 6         3.729001     11.186012
# 7         3.930660     11.312377
# 8         3.832794     11.134358
# 9         4.059047     11.217169
# 10        5.156793     12.102933

# %%
#time of day:
df.groupby('Time')[['Water Temperature', 'Turbidity', 'Transducer Depth', 'Wave Height', 'Wave Period', 'Battery Life']].mean()
# Out:
#              Water Temperature  Turbidity  Transducer Depth  Wave Height  \
# Time
# 01:00:00 AM          19.516370   6.560558          1.568434     0.161573
# 01:00:00 PM          20.052035   5.489886          1.578500     0.175548
# 02:00:00 AM          19.378664   5.452269          1.576500     0.158897
# 02:00:00 PM          20.244824   6.506179          1.578251     0.179186
# 02:20:00 PM                NaN        NaN               NaN          NaN
# 03:00:00 AM          19.270797   6.063111          1.574065     0.158611
# 03:00:00 PM          20.339601   6.013454          1.573862     0.181571
# 03:20:00 PM                NaN        NaN               NaN          NaN
# 03:30:00 PM                NaN        NaN               NaN          NaN
# 04:00:00 AM          19.235359   5.239785          1.572876     0.156743
# 04:00:00 PM          20.346821   5.343093          1.573160     0.184561
# 04:20:00 PM                NaN        NaN               NaN          NaN
# ...

# %%
#years:
df.groupby('Year')[['Water Temperature', 'Turbidity', 'Transducer Depth', 'Wave Height', 'Wave Period', 'Battery Life']].mean()
# Out:
#       Water Temperature  Turbidity  Transducer Depth  Wave Height  \
# Year
# 2013          21.160000   4.170000          1.237200     0.173200
# 2014          19.079105   8.271432          1.570401     0.165053
# 2015          18.595251   4.388865               NaN     0.171838
# 2016          20.947967   1.818600               NaN     0.182710
# 2017          20.055380   2.508552               NaN     0.187000
# 2018          21.371011   1.799277               NaN     0.178454
# 2019          19.803458   2.420350               NaN     0.168164
# 2020          23.810855   1.170263               NaN     0.131726
# 2021          20.729626  13.575326               NaN     0.223154
# 2023                NaN        NaN               NaN     0.133636
# 2024          21.586172  22.296463               NaN     0.116706
#
#       Wave Period  Battery Life
# Year
# 2013     4.800000      9.720000
# 2014     3.863994     10.987705
# 2015     4.025695     11.076138
# ...

# %%
#What is the correlation to battery life to time of day/month?
#what about to beach location?

df.groupby('Time')[['Battery Life']].mean().sort_values(by='Battery Life')
# Out:
#              Battery Life
# Time
# 12:30:00 AM      0.000000
# 04:00:00 AM     11.182714
# 05:00:00 AM     11.200531
# 06:00:00 AM     11.216365
# 03:00:00 AM     11.219653
# 02:00:00 AM     11.228254
# 12:00:00 AM     11.234546
# 10:00:00 PM     11.237241
# 11:00:00 PM     11.242282
# 01:00:00 AM     11.243871
# 09:00:00 PM     11.249166
# 07:00:00 AM     11.249574
# 11:00:00 AM     11.262427
# 08:00:00 PM     11.263092
# 09:00:00 AM     11.263328
# 10:00:00 AM     11.265099
# 08:00:00 AM     11.265825
# 07:00:00 PM     11.271703
# 05:00:00 PM     11.284516
# 06:00:00 PM     11.285357
# 12:00:00 PM     11.286523
# 04:00:00 PM     11.293737
# 01:00:00 PM     11.297602
# 03:00:00 PM     11.297777
# 02:00:00 PM     11.306136
# 11:30:00 AM     12.800000
# 02:20:00 PM           NaN
# 03:20:00 PM           NaN
# 03:30:00 PM           NaN
# 04:20:00 PM           NaN

# %%
#df.groupby('Month')[['Battery Life']].mean().sort_values(by='Battery Life')
df.groupby('Month').mean().sort_values(by='Battery Life')
# Out:
#        Water Temperature  Turbidity  Transducer Depth  Wave Height  \
# Month
# 4              21.700000   3.150000               NaN     0.389000
# 8              22.004947   8.545174          1.594937     0.170761
# 6              17.542685   4.608764          1.534947     0.169373
# 9              20.235338   4.953000          1.630908     0.170799
# 7              20.298675   3.974617          1.587278     0.168488
# 5              14.751655  10.579902          1.456138     0.174384
# 10             15.757143  71.691429               NaN     0.020299
#
#        Wave Period  Battery Life         Year
# Month
# 4         3.000000      0.000000  2018.000000
# 8         3.832794     11.134358  2016.545929
# 6         3.729001     11.186012  2016.065175
# 9         4.059047     11.217169  2017.381037
# 7         3.930660     11.312377  2016.148798
# 5         3.808161     11.802875  2017.991395
# 10        5.156793     12.102933  2022.850667

# %%
df.groupby('Beach Name')[['Battery Life']].mean().sort_values(by='Battery Life')
# Out:
#                         Battery Life
# Beach Name
# 63rd Street Beach          10.774788
# Calumet Beach              10.972391
# Montrose Beach             11.078729
# Osterman Beach             11.138339
# Rainbow Beach              11.198938
# Ohio Street Beach          11.545114
# New Site                         NaN
# Ohio Street Beach Buoy           NaN

# %%
#What is the correlation to water temperature and turbidity to wave height and wave period?

#Wave Period to Water Temperature
with pd.option_context('display.max_rows', None): #<-- display all rows instead of first and last 5
    print(df.groupby('Wave Period')[['Water Temperature']].mean().sort_values(by='Water Temperature'))
# Out:
#              Water Temperature
# Wave Period
# 1.2                  16.400000
# 9.0                  18.494718
# 8.0                  18.818588
# 7.0                  18.941121
# 6.0                  19.027604
# 10.0                 19.141837
# 5.0                  19.150168
# 5.4                  19.184615
# 4.0                  19.198852
# 4.9                  19.625000
# 4.4                  19.864407
# 3.0                  19.870870
# 2.0                  20.073043
# 4.7                  20.303846
# 4.3                  20.364912
# 1.7                  20.602000
# 1.5                  20.631579
# 3.2                  20.647368
# 4.6                  20.665625
# 3.8                  20.745000
# 6.7                  20.914286
# 1.0                  20.950000
# 3.6                  20.978571
# 1.6                  21.057377
# 2.7                  21.089011
# 5.8                  21.112500
# 2.2                  21.182270
# 2.6                  21.236522
# ...

# %%
#Wave Period to Turbidity
with pd.option_context('display.max_rows', None):
    print(df.groupby('Wave Period')[['Turbidity']].mean().sort_values(by='Turbidity'))
# Out:
#              Turbidity
# Wave Period
# 1.0           1.814833
# 10.0          1.947415
# 9.0           2.206849
# 2.0           2.470148
# 3.0           3.607448
# 6.4           3.750915
# 5.8           4.756250
# 5.0           5.008290
# 4.0           5.089782
# 6.1           5.523182
# 5.7           5.658462
# 6.5           5.861845
# 6.3           6.643827
# 6.2           6.662963
# 6.0           7.457454
# 7.3           7.890000
# 5.9           8.639524
# 7.0           9.809581
# 5.6          11.047000
# 6.6          11.209429
# 8.0          11.527565
# 5.4          14.393077
# 5.3          14.672308
# 5.2          16.043333
# 4.5          16.171972
# 4.2          16.245465
# 4.4          16.511864
# 1.3          16.630000
# 5.1          17.370800
# 3.1          17.545686
# 7.4          17.591667
# 7.2          17.855556
# 4.7          18.016923
# 4.6          18.722344
# 3.7          19.286364
# 3.5          19.289756
# 3.9          19.423846
# 4.3          19.507368
# ...

# %%
#Wave Height to Water Temperature
with pd.option_context('display.max_rows', None):
    print(df.groupby('Wave Height')[['Water Temperature']].mean().sort_values(by='Water Temperature'))
# Out:
#              Water Temperature
# Wave Height
# 0.583                 0.000000
# 0.576                 0.000000
# 0.575                 0.000000
# 0.545                 0.000000
# 0.544                 5.600000
# 0.557                 7.933333
# 0.405                 9.125000
# 0.548                 9.700000
# 0.625                 9.800000
# 0.598                 9.900000
# 0.561                10.060000
# 0.606                10.625000
# 0.537                10.633333
# 0.611                11.300000
# 0.509                11.620000
# 0.549                11.700000
# 0.508                11.750000
# 0.591                11.900000
# 0.527                11.950000
# 0.660                12.200000
# 0.541                12.200000
# 0.535                12.220000
# 0.637                12.400000
# 0.543                12.400000
# 0.628                12.500000
# 0.442                12.500000
# 0.626                12.600000
# 0.644                12.900000
# ...

# %%
#Wave Height to Turbidity
with pd.option_context('display.max_rows', None):
    print(df.groupby('Wave Height')[['Turbidity']].mean().sort_values(by='Turbidity'))
# Out:
#               Turbidity
# Wave Height
# 0.028          0.000000
# 0.034          0.000000
# 0.575          0.000000
# 0.025          0.000000
# 0.545          0.000000
# 0.016          0.000000
# 0.583          0.000000
# 0.576          0.000000
# 0.017          0.018000
# 0.018          0.023333
# 0.021          0.025000
# 0.014          0.044348
# 0.019          0.050000
# 0.015          0.130909
# 0.013          0.135714
# 0.038          0.230000
# 0.035          0.250000
# 0.039          0.290000
# 0.041          0.333333
# 0.042          0.350000
# 0.045          0.470000
# 0.043          0.512857
# 0.044          0.516667
# 0.008          0.520000
# 0.046          0.522000
# 0.048          0.600000
# 1.229          0.600000
# 0.052          0.660714
# 0.051          0.674444
# 0.049          0.728333
# 0.047          0.755000
# 0.000          0.909463
# 0.055          0.926429
# 0.058          0.961053
# 0.061          0.973846
# 0.059          1.018478
# ...
